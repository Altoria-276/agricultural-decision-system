# %%
from dataprocess import Map
import os
import pandas as pd

# %%
map = Map(os.path.join("数据", "湘潭县界.shp"))

# %%
params_name_2 = [
    "基准",
    "2008年",
    "2009年",
    "2010年",
    "2011年",
    "2012年",
    "2013年",
    "2014年",
    "2015年",
    "2016年",
    "2017年",
    "2018年",
    "2019年",
    "2020年",
    "2021年",
    "2022年",
    "2023年",
    "2024年",
]

# %%
map.load_dots_df(pd.read_excel("多年数据\data.xlsx"),params_name_2)

# %%
df = pd.read_excel("多年数据\data.xlsx")

# %%
df.columns
# Out:
# Index(['序号', '东经', '北纬', '基准', '2008年', '2009年', '2010年', '2011年', '2012年',
#        '2013年', '2014年', '2015年', '2016年', '2017年', '2018年', '2019年', '2020年',
#        '2021年', '2022年', '2023年', '2024年'],
#       dtype='object')

# %%
df
# Out:
#       序号         东经        北纬    基准     2008年     2009年     2010年     2011年  \
# 0     62  112.93650  27.47160  0.31  0.394011  0.318087  0.333260  0.431903
# 1     63  112.89400  27.45010  0.42  0.476977  0.641305  0.756804  1.013067
# 2     64  112.85260  27.47830  0.31  0.408057  0.424034  0.620543  0.840822
# 3     65  112.91240  27.48150  0.46  0.514760  0.693898  0.773064  1.020961
# 4     66  112.93860  27.47790  0.95  1.091594  1.179815  1.347527  1.249191
# ..   ...        ...       ...   ...       ...       ...       ...       ...
# 143  134  112.87522  27.54506  0.52  0.528025  0.469509  0.540868  0.396459
# 144  135  112.95279  27.51057  0.65  0.745557  0.923340  1.059889  1.168359
# 145  136  112.84000  27.57000  0.58  0.565522  0.634767  0.811427  0.786152
# 146  137  112.91651  27.54054  1.40  1.531626  1.706084  1.796364  1.839186
# 147  138  112.93189  27.57740  0.62  0.729282  0.723625  0.885488  0.921544
#
# ...
