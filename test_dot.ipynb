# %%
from geomap import GeoMap
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
gmap = GeoMap(os.path.join("数据", "湘潭县界.shp"))
space = ["东经", "北纬"]

# %%
params_name_2 = [
    "基准",
    "2008年",
    "2009年",
    "2010年",
    "2011年",
    "2012年",
    "2013年",
    "2014年",
    "2015年",
    "2016年",
    "2017年",
    "2018年",
    "2019年",
    "2020年",
    "2021年",
    "2022年",
    "2023年",
    "2024年",
]

# %%
gmap.load_dots_df(pd.read_excel("多年数据\data.xlsx"),params_name_2)

# %%
gmap.dots_list
# Out:
# [Dot(lon=112.9365, lat=27.4716, params={'基准': 0.31, '2008年': 0.5213989509424672, '2009年': 0.7617502263993842, '2010年': 0.8638010602308233, '2011年': 0.9568307103557321, '2012年': 1.1585687068190027, '2013年': 1.161434171285977, '2014年': 1.409673896061566, '2015年': 1.4761664498862384, '2016年': 1.66623423153235, '2017年': 1.681286104490469, '2018年': 1.7433624525759108, '2019年': 1.8394829526151513, '2020年': 2.164181865932422, '2021年': 2.176588609187162, '2022年': 2.2122628055919074, '2023年': 2.3688027351212884, '2024年': 2.225576076399024}),
# ...

# %%
gmap.outline.bounds
# Out:
# (112.42127808, 27.33803919, 113.05893888, 27.94195017)

# %%
gmap.save_dot_image()
# Out:
# '.\\Images\\img_dot_2012年.png'
